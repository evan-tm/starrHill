# %% [markdown]
# ## Census Data Retrieval

# %%
import datetime


print('Last Updated On: ', datetime.datetime.now())
# Out:
# Last Updated On:  2022-06-21 21:32:06.117356

# %%
import censusdata
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
NA_VALUE = -666666666
blockNeighborDict = {
    10001: 'Starr Hill', # 10001
    8001: 'Greenbrier', # 8001
    5012: 'Fifeville', # 5012
    7003: 'Barracks Road', # 7003
    7001: 'Barracks / Rugby', # 7001
    2012: 'Rose Hill', # 2012
    2022: 'Venable', # 2022
    4022: 'Belmont', # 4022
    3021: 'Martha Jefferson', # 3021
    5024: 'Fry\'s Spring', # 5024
    4011: 'Ridge Street', # 4011
    9001: 'Locust Grove', # 9001
    8002: 'Greenbrier', # 8002
    5021: 'Johnson Village', # 5021
    2023: 'Venable', # 2023
    8003: 'Greenbrier', # 8003
    8004: 'The Meadows', # 8004
    5013: 'Fifeville', # 5013
    5011: 'Fifeville', # 5011
    7004: 'Lewis Mountain', # 7004
    7002: 'Venable', # 7002
    5025: 'Fry\'s Spring', # 5025
    5022: 'Fry\'s Spring', # 5022
    5023: 'Fry\'s Spring', # 5023
    10002: 'North Downtown', # 10002
    10003: 'North Downtown', # 10003
    2013: 'Venable', # 2013
    2011: 'Barracks / Rugby', # 2011
    2021: '10th & Page', # 2021
    4023: 'Belmont', # 4023
    4024: 'Belmont', # 4024
    3022: 'Woolen Mills', # 3022
    4012: 'Ridge Street', # 4012
    9002: 'Locust Grove', # 9002
    6002: 'Jefferson Park Avenue', # 6002
    6001: 'Jefferson Park Avenue', # 6001
    4021: 'Belmont', # 4021
    6003: 'Jefferson Park Avenue' # 6003
}
uniqueNeighborhoods = list(set(blockNeighborDict.values()))
uniqueNeighborhoods.sort()

# %% [markdown]
# ### Data retrieval for age:

# %%
censusdata.printtable(censusdata.censustable('acs5', 2019, 'B01001'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B01001_001E  | SEX BY AGE                     | !! Estimate Total:                                       | int
# B01001_002E  | SEX BY AGE                     | !! !! Estimate Total: Male:                              | int
# B01001_003E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: Under 5 years             | int
# B01001_004E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 5 to 9 years              | int
# B01001_005E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 10 to 14 years            | int
# B01001_006E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 15 to 17 years            | int
# B01001_007E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 18 and 19 years           | int
# B01001_008E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 20 years                  | int
# B01001_009E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 21 years                  | int
# B01001_010E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 22 to 24 years            | int
# B01001_011E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 25 to 29 years            | int
# B01001_012E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 30 to 34 years            | int
# B01001_013E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 35 to 39 years            | int
# B01001_014E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 40 to 44 years            | int
# B01001_015E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 45 to 49 years            | int
# B01001_016E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 50 to 54 years            | int
# B01001_017E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 55 to 59 years            | int
# B01001_018E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 60 and 61 years           | int
# B01001_019E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 62 to 64 years            | int
# B01001_020E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 65 and 66 years           | int
# B01001_021E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 67 to 69 years            | int
# B01001_022E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 70 to 74 years            | int
# B01001_023E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 75 to 79 years            | int
# B01001_024E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 80 to 84 years            | int
# B01001_025E  | SEX BY AGE                     | !! !! !! Estimate Total: Male: 85 years and over         | int
# B01001_026E  | SEX BY AGE                     | !! !! Estimate Total: Female:                            | int
# B01001_027E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: Under 5 years           | int
# B01001_028E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 5 to 9 years            | int
# B01001_029E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 10 to 14 years          | int
# B01001_030E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 15 to 17 years          | int
# B01001_031E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 18 and 19 years         | int
# B01001_032E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 20 years                | int
# B01001_033E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 21 years                | int
# B01001_034E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 22 to 24 years          | int
# B01001_035E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 25 to 29 years          | int
# B01001_036E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 30 to 34 years          | int
# B01001_037E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 35 to 39 years          | int
# B01001_038E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 40 to 44 years          | int
# B01001_039E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 45 to 49 years          | int
# B01001_040E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 50 to 54 years          | int
# B01001_041E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 55 to 59 years          | int
# B01001_042E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 60 and 61 years         | int
# B01001_043E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 62 to 64 years          | int
# B01001_044E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 65 and 66 years         | int
# B01001_045E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 67 to 69 years          | int
# B01001_046E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 70 to 74 years          | int
# B01001_047E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 75 to 79 years          | int
# B01001_048E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 80 to 84 years          | int
# B01001_049E  | SEX BY AGE                     | !! !! !! Estimate Total: Female: 85 years and over       | int
# -------------------------------------------------------------------------------------------------------------------

# %%
# Function to grab data from Charlottesville City Table B01001
# In: year
# Out: dataframe containing sex by age table for overall city
def get01001DataCity(year):
    # create list of variables to pull for male column
    maleVar = ['B01001_0{:02d}E'.format(x) for x in range(3, 26)]
    # download age data for males
    dfAgeMale = censusdata.download('acs5', year, 
                                    censusdata.censusgeo([('state', '51'), 
                                                      ('county', '540')]),
                                    maleVar)
    dfAgeMale = dfAgeMale.T
    # renaming column and rows
    dfAgeMale = dfAgeMale.rename(columns={dfAgeMale.columns[0]: 'Male'},
                                 index={'B01001_003E': '0 to 4',
                                          'B01001_004E': '5 to 9',
                                          'B01001_005E': '10 to 14',
                                          'B01001_006E': '15 to 17',
                                          'B01001_007E': '18 and 19',
                                          'B01001_008E': '20',
                                          'B01001_009E': '21',
                                          'B01001_010E': '22 to 24',
                                          'B01001_011E': '25 to 29',
                                          'B01001_012E': '30 to 34',
                                          'B01001_013E': '35 to 39',
                                          'B01001_014E': '40 to 44',
                                          'B01001_015E': '45 to 49',
                                          'B01001_016E': '50 to 54',
                                          'B01001_017E': '55 to 59',
                                          'B01001_018E': '60 and 61',
                                          'B01001_019E': '62 to 64',
                                          'B01001_020E': '65 and 66',
                                          'B01001_021E': '67 to 69',
                                          'B01001_022E': '70 to 74',
                                          'B01001_023E': '75 to 79',
                                          'B01001_024E': '80 to 84', 
                                          'B01001_025E': '85 and up'})
    dfAgeMale.loc['15 to 17'] += dfAgeMale.loc['18 and 19']
    dfAgeMale.drop(['18 and 19'], inplace=True)
    dfAgeMale.loc['20'] += dfAgeMale.loc['21'] + dfAgeMale.loc['22 to 24']
    dfAgeMale.drop(['21'], inplace=True)
    dfAgeMale.drop(['22 to 24'], inplace=True)
    dfAgeMale.loc['60 and 61'] += dfAgeMale.loc['62 to 64']
    dfAgeMale.drop(['62 to 64'], inplace=True)
    dfAgeMale.loc['65 and 66'] += dfAgeMale.loc['67 to 69']
    dfAgeMale.drop(['67 to 69'], inplace=True)
    dfAgeMale = dfAgeMale.rename(index={'15 to 17': '15 to 19',
                                        '20': '20 to 24',
                                        '60 and 61': '60 to 64',
                                        '65 and 66': '65 to 69'})
    # create list of variables to pull for female column
    femaleVar = ['B01001_0{:02d}E'.format(x) for x in range(27, 50)]
    # download age data for females
    dfAgeFemale = censusdata.download('acs5', year, 
                                      censusdata.censusgeo([('state', '51'), 
                                                      ('county', '540')]),
                                      femaleVar)
    dfAgeFemale = dfAgeFemale.T
    # renaming column and rows
    dfAgeFemale = dfAgeFemale.rename(columns={dfAgeFemale.columns[0]: 'Female'},
                                     index={'B01001_027E': '0 to 4',
                                          'B01001_028E': '5 to 9',
                                          'B01001_029E': '10 to 14',
                                          'B01001_030E': '15 to 17',
                                          'B01001_031E': '18 and 19',
                                          'B01001_032E': '20',
                                          'B01001_033E': '21',
                                          'B01001_034E': '22 to 24',
                                          'B01001_035E': '25 to 29',
                                          'B01001_036E': '30 to 34',
                                          'B01001_037E': '35 to 39',
                                          'B01001_038E': '40 to 44',
                                          'B01001_039E': '45 to 49',
                                          'B01001_040E': '50 to 54',
                                          'B01001_041E': '55 to 59',
                                          'B01001_042E': '60 and 61',
                                          'B01001_043E': '62 to 64',
                                          'B01001_044E': '65 and 66',
                                          'B01001_045E': '67 to 69',
                                          'B01001_046E': '70 to 74',
                                          'B01001_047E': '75 to 79',
                                          'B01001_048E': '80 to 84', 
                                          'B01001_049E': '85 and up'})
    dfAgeFemale.loc['15 to 17'] += dfAgeFemale.loc['18 and 19']
    dfAgeFemale.drop(['18 and 19'], inplace=True)
    dfAgeFemale.loc['20'] += dfAgeFemale.loc['21'] + dfAgeFemale.loc['22 to 24']
    dfAgeFemale.drop(['21'], inplace=True)
    dfAgeFemale.drop(['22 to 24'], inplace=True)
    dfAgeFemale.loc['60 and 61'] += dfAgeFemale.loc['62 to 64']
    dfAgeFemale.drop(['62 to 64'], inplace=True)
    dfAgeFemale.loc['65 and 66'] += dfAgeFemale.loc['67 to 69']
    dfAgeFemale.drop(['67 to 69'], inplace=True)
    dfAgeFemale = dfAgeFemale.rename(index={'15 to 17': '15 to 19',
                                        '20': '20 to 24',
                                        '60 and 61': '60 to 64',
                                        '65 and 66': '65 to 69'})
    dfAge = dfAgeMale
    dfAge['Female'] = dfAgeFemale['Female']
    # get total population count
    totalPop = dfAge['Male'].sum() + dfAge['Female'].sum()
    # get pct df from counts
    dfAgePct = dfAge.apply(lambda x: 100 * x / float(totalPop))
    dfAgeFull = pd.concat([dfAgePct, dfAge], axis=1, join='inner')
    dfAgeFull.columns.values[2:] = dfAgeFull.columns.values[2:] + 'ct'
    dfAgeFull['Year'] = year

    return dfAgeFull

# %%
def get01001Historical(years, hood = False):
    for year in years:
        if hood:
            if year == years[0]:
                df = get01001DataHood(year)
            else:
                df = pd.concat([df, get01001DataHood(year)])
        else:
            if year == years[0]:
                df = get01001DataCity(year)
            else:
                df = pd.concat([df, get01001DataCity(year)])
    df.index.name = 'Age'
    return df

# %%
dfAge = get01001Historical([year for year in range(2009, 2021)])

# %%
dfAge
# Out:
#                 Male     Female  Malect  Femalect  Year
# Age
# 0 to 4      2.754089   2.708187    1140      1121  2009
# 5 to 9      2.488343   2.256420    1030       934  2009
# 10 to 14    2.019665   1.659701     836       687  2009
# 15 to 19    3.660039   4.177035    1515      1729  2009
# 20 to 24   11.192714  12.154229    4633      5031  2009
# ...              ...        ...     ...       ...   ...
# 65 to 69    1.785374   2.325434     843      1098  2020
# 70 to 74    1.529110   1.673126     722       790  2020
# 75 to 79    0.724315   0.989051     342       467  2020
# 80 to 84    0.578182   0.639600     273       302  2020
# 85 and up   0.370629   1.147892     175       542  2020
#
# [216 rows x 5 columns]

# %% [markdown]
# dfAge.to_csv('data/ageCity.csv')

# %%
# Function to grab data from Charlottesville City Table B01001
# In: year
# Out: dataframe containing sex by age table for neighborhoods
def get01001DataHood(year):
    # create list of variables to pull for male column
    maleVar = ['B01001_0{:02d}E'.format(x) for x in range(3, 26)]
    # download age data for males
    dfAgeMale = censusdata.download('acs5', year, 
                                    censusdata.censusgeo([('state', '51'), 
                                                          ('county', '540'),
                                                          ('block group', '*')]),
                                    maleVar)
    # add neighborhoods for grouping
    dfAgeMale['Neighborhood'] = ''
    for index, row in dfAgeMale.iterrows():
        if index.geo[2][1][2]:
            # 100 census tract case
            dfAgeMale.loc[index, 'Neighborhood'] = blockNeighborDict[int(index.geo[2][1][2:] + \
                                                                         index.geo[3][1])]
        else:
            # 0xx census tract case
            dfAgeMale.loc[index, 'Neighborhood'] = blockNeighborDict[int(index.geo[2][1][3:] + \
                                                                         index.geo[3][1])]
    # remove nan values and sum neighborhood counts
    dfAgeMale = dfAgeMale.groupby('Neighborhood').sum().astype(int)
    # transpose
    dfAgeMale = dfAgeMale.T
    # renaming rows
    dfAgeMale = dfAgeMale.rename(index={'B01001_003E': '0 to 4',
                                        'B01001_004E': '5 to 9',
                                        'B01001_005E': '10 to 14',
                                        'B01001_006E': '15 to 17',
                                        'B01001_007E': '18 and 19',
                                        'B01001_008E': '20',
                                        'B01001_009E': '21',
                                        'B01001_010E': '22 to 24',
                                        'B01001_011E': '25 to 29',
                                        'B01001_012E': '30 to 34',
                                        'B01001_013E': '35 to 39',
                                        'B01001_014E': '40 to 44',
                                        'B01001_015E': '45 to 49',
                                        'B01001_016E': '50 to 54',
                                        'B01001_017E': '55 to 59',
                                        'B01001_018E': '60 and 61',
                                        'B01001_019E': '62 to 64',
                                        'B01001_020E': '65 and 66',
                                        'B01001_021E': '67 to 69',
                                        'B01001_022E': '70 to 74',
                                        'B01001_023E': '75 to 79',
                                        'B01001_024E': '80 to 84', 
                                        'B01001_025E': '85 and up'})
    # combining some age groups to have even sizes
    dfAgeMale.loc['15 to 17'] += dfAgeMale.loc['18 and 19']
    dfAgeMale.drop(['18 and 19'], inplace=True)
    dfAgeMale.loc['20'] += dfAgeMale.loc['21'] + dfAgeMale.loc['22 to 24']
    dfAgeMale.drop(['21'], inplace=True)
    dfAgeMale.drop(['22 to 24'], inplace=True)
    dfAgeMale.loc['60 and 61'] += dfAgeMale.loc['62 to 64']
    dfAgeMale.drop(['62 to 64'], inplace=True)
    dfAgeMale.loc['65 and 66'] += dfAgeMale.loc['67 to 69']
    dfAgeMale.drop(['67 to 69'], inplace=True)
    # renaming combined groups
    dfAgeMale = dfAgeMale.rename(index={'15 to 17': '15 to 19',
                                        '20': '20 to 24',
                                        '60 and 61': '60 to 64',
                                        '65 and 66': '65 to 69'})
    # create list of variables to pull for female column
    femaleVar = ['B01001_0{:02d}E'.format(x) for x in range(27, 50)]
    # download age data for females
    dfAgeFemale = censusdata.download('acs5', year, 
                                      censusdata.censusgeo([('state', '51'), 
                                                            ('county', '540'),
                                                            ('block group', '*')]),
                                      femaleVar)
    # add neighborhoods for grouping
    dfAgeFemale['Neighborhood'] = ''
    for index, row in dfAgeFemale.iterrows():
        if index.geo[2][1][2]:
            # 100 census tract case
            dfAgeFemale.loc[index, 'Neighborhood'] = blockNeighborDict[int(index.geo[2][1][2:] + \
                                                                           index.geo[3][1])]
        else:
            # 0xx census tract case
            dfAgeFemale.loc[index, 'Neighborhood'] = blockNeighborDict[int(index.geo[2][1][3:] + \
                                                                           index.geo[3][1])]
    # remove nan values and sum neighborhood counts
    dfAgeFemale = dfAgeFemale.groupby('Neighborhood').sum().astype(int)
    # transpose
    dfAgeFemale = dfAgeFemale.T
    # renaming column and rows
    dfAgeFemale = dfAgeFemale.rename(index={'B01001_027E': '0 to 4',
                                            'B01001_028E': '5 to 9',
                                            'B01001_029E': '10 to 14',
                                            'B01001_030E': '15 to 17',
                                            'B01001_031E': '18 and 19',
                                            'B01001_032E': '20',
                                            'B01001_033E': '21',
                                            'B01001_034E': '22 to 24',
                                            'B01001_035E': '25 to 29',
                                            'B01001_036E': '30 to 34',
                                            'B01001_037E': '35 to 39',
                                            'B01001_038E': '40 to 44',
                                            'B01001_039E': '45 to 49',
                                            'B01001_040E': '50 to 54',
                                            'B01001_041E': '55 to 59',
                                            'B01001_042E': '60 and 61',
                                            'B01001_043E': '62 to 64',
                                            'B01001_044E': '65 and 66',
                                            'B01001_045E': '67 to 69',
                                            'B01001_046E': '70 to 74',
                                            'B01001_047E': '75 to 79',
                                            'B01001_048E': '80 to 84', 
                                            'B01001_049E': '85 and up'})
    # combining some age groups to have even sizes
    dfAgeFemale.loc['15 to 17'] += dfAgeFemale.loc['18 and 19']
    dfAgeFemale.drop(['18 and 19'], inplace=True)
    dfAgeFemale.loc['20'] += dfAgeFemale.loc['21'] + dfAgeFemale.loc['22 to 24']
    dfAgeFemale.drop(['21'], inplace=True)
    dfAgeFemale.drop(['22 to 24'], inplace=True)
    dfAgeFemale.loc['60 and 61'] += dfAgeFemale.loc['62 to 64']
    dfAgeFemale.drop(['62 to 64'], inplace=True)
    dfAgeFemale.loc['65 and 66'] += dfAgeFemale.loc['67 to 69']
    dfAgeFemale.drop(['67 to 69'], inplace=True)
    # renaming combined groups
    dfAgeFemale = dfAgeFemale.rename(index={'15 to 17': '15 to 19',
                                            '20': '20 to 24',
                                            '60 and 61': '60 to 64',
                                            '65 and 66': '65 to 69'})
    # join male/female datasets and add variable identifier
    dfAge = pd.concat([dfAgeMale, dfAgeFemale], axis=1, join='inner')
    dfAge.columns.values[:19] = dfAge.columns.values[:19] + '_M'
    dfAge.columns.values[19:] = dfAge.columns.values[19:] + '_F'
    # generating pct df
    dfAgePct = dfAge
    for hood in uniqueNeighborhoods:
        totalPop = dfAge[hood + "_M"].sum() + dfAge[hood + "_F"].sum()
        dfAgePct[hood + "_M"] = 100 * dfAgePct[hood + "_M"] / float(totalPop)
        dfAgePct[hood + "_F"] = 100 * dfAgePct[hood + "_F"] / float(totalPop)
    # combining pct and ct df
    dfAgeFull = pd.concat([dfAgePct, dfAge], axis=1, join='inner')
    dfAgeFull.columns.values[38:] = dfAgeFull.columns.values[38:] + "ct"
    # add year
    dfAgeFull['Year'] = year

    return dfAgeFull

# %%
dfAgeHood = get01001Historical([year for year in range(2013, 2021)], True)

# %%
dfAgeHood
# Out:
# Neighborhood  10th & Page_M  Barracks / Rugby_M  Barracks Road_M  Belmont_M  \
# Age
# 0 to 4             0.349243            4.497099         0.000000   2.617535
# 5 to 9             4.307334            2.417795         0.000000   3.761118
# 10 to 14           0.000000            0.967118         0.000000   1.601017
# 15 to 19           4.656577            2.417795         5.287356   3.405337
# 20 to 24           0.000000            5.029014        17.931034   4.193139
# ...                     ...                 ...              ...        ...
# 65 to 69           0.000000            8.982376         0.000000   1.305294
# 70 to 74           0.000000            2.046617         0.000000   2.054629
# 75 to 79           0.000000            1.364412         0.000000   1.426154
# 80 to 84           0.000000            0.000000         0.000000   0.290065
# 85 and up          0.000000            0.227402         0.000000   0.700991
#
# Neighborhood  Fifeville_M  Fry's Spring_M  Greenbrier_M  \
# Age
# 0 to 4           3.445354        3.404122      3.163993
# 5 to 9           3.586557        0.000000      2.852050
# 10 to 14         4.264332        1.249219      0.668449
# 15 to 19         3.897204        1.374141      2.005348
# 20 to 24         5.139791        6.121174      0.757576
# ...                   ...             ...           ...
# 65 to 69         1.332751        1.058371      5.640535
# 70 to 74         2.010050        0.000000      2.485660
# 75 to 79         0.065545        0.000000      2.151052
# 80 to 84         0.043697        0.000000      0.525813
# 85 and up        0.000000        0.930083      0.000000
#
# Neighborhood  Jefferson Park Avenue_M  Johnson Village_M  Lewis Mountain_M  \
# Age
# 0 to 4                       0.468436           8.208092          0.000000
# 5 to 9                       0.133839           3.468208          0.000000
# 10 to 14                     0.401517           0.751445          0.000000
# 15 to 19                    10.617890           5.202312          4.044118
# 20 to 24                    16.975240           6.936416         27.328431
# ...                               ...                ...               ...
# 65 to 69                     2.660319           0.000000          0.000000
# 70 to 74                     0.392047           2.467917          0.955414
# 75 to 79                     0.728087           1.974334          1.167728
# 80 to 84                     0.840101           1.875617          1.167728
# 85 and up                    0.000000           0.000000          1.167728
#
# Neighborhood  Locust Grove_M  Martha Jefferson_M  North Downtown_M  \
# Age
# 0 to 4              6.563877            2.681159          3.827038
# 5 to 9              1.365639            1.811594          1.491054
# 10 to 14            1.585903            2.898551          1.838966
# 15 to 19            4.581498            2.971014          0.646123
# 20 to 24            1.629956            0.000000          1.192843
# ...                      ...                 ...               ...
# 65 to 69            4.404873            2.495840          1.104159
# 70 to 74            1.405811            0.554631          2.429150
# 75 to 79            0.468604            2.384914          0.736106
# 80 to 84            0.749766            0.942873          0.110416
# 85 and up           0.468604            1.109262          0.478469
#
# Neighborhood  Ridge Street_M  Rose Hill_M  Starr Hill_M  The Meadows_M  \
# Age
# 0 to 4              3.115547     2.470356      0.000000       4.709937
# 5 to 9              4.053237     2.470356      1.334951       7.811603
# 10 to 14            4.809437     0.691700      0.000000       4.422746
# 15 to 19            4.204477     0.000000      1.213592       4.997128
# 20 to 24            4.264973    11.857708      0.849515       1.091327
# ...                      ...          ...           ...            ...
# 65 to 69            1.346332     1.328502      4.467005       0.759878
# 70 to 74            0.441040     3.019324     15.126904       2.203647
# 75 to 79            0.371402     0.724638      2.335025       0.000000
# 80 to 84            0.232126     0.000000      1.319797       1.975684
# 85 and up           0.464253     0.000000      1.624365       0.000000
#
# Neighborhood  Venable_M  Woolen Mills_M  10th & Page_F  Barracks / Rugby_F  \
# Age
# 0 to 4         0.967600        1.626016       5.355064            2.901354
# 5 to 9         0.982261        3.252033       3.026775            4.545455
# 10 to 14       0.557103        1.422764       3.608847            3.094778
# 15 to 19       8.136637        1.321138       0.000000            2.079304
# 20 to 24      22.782583        5.792683       4.307334            2.901354
# ...                 ...             ...            ...                 ...
# 65 to 69       0.267380        0.977444       4.681404            1.250711
# 70 to 74       0.675486        0.601504       0.000000            1.932916
# 75 to 79       0.000000        1.203008       0.000000            0.341103
# 80 to 84       0.985083        1.052632       0.065020            0.284252
# 85 and up      0.323670        0.000000       0.065020            0.682206
#
# Neighborhood  Barracks Road_F  Belmont_F  Fifeville_F  Fry's Spring_F  \
# Age
# 0 to 4               5.287356   1.728081     2.569896        2.498438
# 5 to 9               0.000000   1.194409     2.005083        0.000000
# 10 to 14             1.379310   1.677255     2.993505        1.093067
# 15 to 19            15.862069   1.855146     1.920361        2.560899
# 20 to 24            24.137931   3.456163     5.196272        5.215490
# ...                       ...        ...          ...             ...
# 65 to 69             0.000000   1.595359     1.267206        0.000000
# 70 to 74             0.000000   2.610587     0.961328        0.833868
# 75 to 79             0.000000   0.749335     1.857112        0.609365
# 80 to 84             0.000000   0.604303     0.284029        0.962155
# 85 and up            0.000000   0.628475     1.594931        3.752405
#
# Neighborhood  Greenbrier_F  Jefferson Park Avenue_F  Johnson Village_F  \
# Age
# 0 to 4            3.431373                 0.468436           5.317919
# 5 to 9            3.297683                 0.133839           1.098266
# 10 to 14          4.233512                 0.401517           5.491329
# 15 to 19          1.604278                 7.539594           0.867052
# 20 to 24          2.450980                34.374303           8.497110
# ...                    ...                      ...                ...
# 65 to 69          7.456979                 0.868104           2.813425
# 70 to 74          6.453155                 0.112013           5.429418
# 75 to 79          1.625239                 0.140017           3.455084
# 80 to 84          1.720841                 0.196024           0.789733
# 85 and up         1.147228                 0.000000           0.000000
#
# Neighborhood  Lewis Mountain_F  Locust Grove_F  Martha Jefferson_F  \
# Age
# 0 to 4                0.000000        2.555066            7.608696
# 5 to 9                0.000000        1.233480            3.405797
# 10 to 14              0.000000        2.731278            1.739130
# 15 to 19              9.436275        0.704846            0.000000
# 20 to 24             19.975490        2.863436            3.188406
# ...                        ...             ...                 ...
# 65 to 69             11.040340        2.999063            2.773156
# 70 to 74              0.000000        0.328022            0.000000
# 75 to 79              0.743100        3.561387            1.552967
# 80 to 84              0.424628        1.733833            0.332779
# 85 and up             0.530786        0.749766            0.221852
#
# Neighborhood  North Downtown_F  Ridge Street_F  Rose Hill_F  Starr Hill_F  \
# Age
# 0 to 4                3.628231        4.597701     0.000000      0.000000
# 5 to 9                3.031809        2.813067     0.000000      1.456311
# 10 to 14              2.087475        1.391410     4.150198      0.000000
# 15 to 19              1.242545        2.329099     0.592885      0.728155
# 20 to 24              4.522863        3.024803     6.521739      6.674757
# ...                        ...             ...          ...           ...
# 65 to 69              2.429150        1.740947     5.797101      0.913706
# 70 to 74              0.736106        2.715877     5.072464      7.715736
# 75 to 79              0.699301        0.626741     0.966184      0.507614
# 80 to 84              0.662495        0.417827     0.724638      4.974619
# 85 and up             0.220832        0.626741     2.053140      5.482234
#
# Neighborhood  The Meadows_F  Venable_F  Woolen Mills_F  10th & Page_Mct  \
# Age
# 0 to 4             5.916140   0.689049        3.150407         0.349243
# 5 to 9             1.665709   0.542442        1.016260         4.307334
# 10 to 14           1.665709   0.469139        7.418699         0.000000
# 15 to 19           0.919012   5.145873        0.000000         4.656577
# 20 to 24           2.125215  32.473244        6.707317         0.000000
# ...                     ...        ...             ...              ...
# 65 to 69           1.063830   0.295525       13.909774         0.000000
# 70 to 74           1.823708   0.605122        0.000000         0.000000
# 75 to 79           0.683891   0.154799        2.030075         0.000000
# 80 to 84           0.683891   0.309598        0.000000         0.000000
# 85 and up          4.331307   1.308753        0.751880         0.000000
#
# Neighborhood  Barracks / Rugby_Mct  Barracks Road_Mct  Belmont_Mct  \
# Age
# 0 to 4                    4.497099           0.000000     2.617535
# 5 to 9                    2.417795           0.000000     3.761118
# 10 to 14                  0.967118           0.000000     1.601017
# 15 to 19                  2.417795           5.287356     3.405337
# 20 to 24                  5.029014          17.931034     4.193139
# ...                            ...                ...          ...
# 65 to 69                  8.982376           0.000000     1.305294
# 70 to 74                  2.046617           0.000000     2.054629
# 75 to 79                  1.364412           0.000000     1.426154
# 80 to 84                  0.000000           0.000000     0.290065
# 85 and up                 0.227402           0.000000     0.700991
#
# Neighborhood  Fifeville_Mct  Fry's Spring_Mct  Greenbrier_Mct  \
# Age
# 0 to 4             3.445354          3.404122        3.163993
# 5 to 9             3.586557          0.000000        2.852050
# 10 to 14           4.264332          1.249219        0.668449
# 15 to 19           3.897204          1.374141        2.005348
# 20 to 24           5.139791          6.121174        0.757576
# ...                     ...               ...             ...
# 65 to 69           1.332751          1.058371        5.640535
# 70 to 74           2.010050          0.000000        2.485660
# 75 to 79           0.065545          0.000000        2.151052
# 80 to 84           0.043697          0.000000        0.525813
# 85 and up          0.000000          0.930083        0.000000
#
# Neighborhood  Jefferson Park Avenue_Mct  Johnson Village_Mct  \
# Age
# 0 to 4                         0.468436             8.208092
# 5 to 9                         0.133839             3.468208
# 10 to 14                       0.401517             0.751445
# 15 to 19                      10.617890             5.202312
# 20 to 24                      16.975240             6.936416
# ...                                 ...                  ...
# 65 to 69                       2.660319             0.000000
# 70 to 74                       0.392047             2.467917
# 75 to 79                       0.728087             1.974334
# 80 to 84                       0.840101             1.875617
# 85 and up                      0.000000             0.000000
#
# Neighborhood  Lewis Mountain_Mct  Locust Grove_Mct  Martha Jefferson_Mct  \
# Age
# 0 to 4                  0.000000          6.563877              2.681159
# 5 to 9                  0.000000          1.365639              1.811594
# 10 to 14                0.000000          1.585903              2.898551
# 15 to 19                4.044118          4.581498              2.971014
# 20 to 24               27.328431          1.629956              0.000000
# ...                          ...               ...                   ...
# 65 to 69                0.000000          4.404873              2.495840
# 70 to 74                0.955414          1.405811              0.554631
# 75 to 79                1.167728          0.468604              2.384914
# 80 to 84                1.167728          0.749766              0.942873
# 85 and up               1.167728          0.468604              1.109262
#
# Neighborhood  North Downtown_Mct  Ridge Street_Mct  Rose Hill_Mct  \
# Age
# 0 to 4                  3.827038          3.115547       2.470356
# 5 to 9                  1.491054          4.053237       2.470356
# 10 to 14                1.838966          4.809437       0.691700
# 15 to 19                0.646123          4.204477       0.000000
# 20 to 24                1.192843          4.264973      11.857708
# ...                          ...               ...            ...
# 65 to 69                1.104159          1.346332       1.328502
# 70 to 74                2.429150          0.441040       3.019324
# 75 to 79                0.736106          0.371402       0.724638
# 80 to 84                0.110416          0.232126       0.000000
# 85 and up               0.478469          0.464253       0.000000
#
# Neighborhood  Starr Hill_Mct  The Meadows_Mct  Venable_Mct  Woolen Mills_Mct  \
# Age
# 0 to 4              0.000000         4.709937     0.967600          1.626016
# 5 to 9              1.334951         7.811603     0.982261          3.252033
# 10 to 14            0.000000         4.422746     0.557103          1.422764
# 15 to 19            1.213592         4.997128     8.136637          1.321138
# 20 to 24            0.849515         1.091327    22.782583          5.792683
# ...                      ...              ...          ...               ...
# 65 to 69            4.467005         0.759878     0.267380          0.977444
# 70 to 74           15.126904         2.203647     0.675486          0.601504
# 75 to 79            2.335025         0.000000     0.000000          1.203008
# 80 to 84            1.319797         1.975684     0.985083          1.052632
# 85 and up           1.624365         0.000000     0.323670          0.000000
#
# Neighborhood  10th & Page_Fct  Barracks / Rugby_Fct  Barracks Road_Fct  \
# Age
# 0 to 4               5.355064              2.901354           5.287356
# 5 to 9               3.026775              4.545455           0.000000
# 10 to 14             3.608847              3.094778           1.379310
# 15 to 19             0.000000              2.079304          15.862069
# 20 to 24             4.307334              2.901354          24.137931
# ...                       ...                   ...                ...
# 65 to 69             4.681404              1.250711           0.000000
# 70 to 74             0.000000              1.932916           0.000000
# 75 to 79             0.000000              0.341103           0.000000
# 80 to 84             0.065020              0.284252           0.000000
# 85 and up            0.065020              0.682206           0.000000
#
# Neighborhood  Belmont_Fct  Fifeville_Fct  Fry's Spring_Fct  Greenbrier_Fct  \
# Age
# 0 to 4           1.728081       2.569896          2.498438        3.431373
# 5 to 9           1.194409       2.005083          0.000000        3.297683
# 10 to 14         1.677255       2.993505          1.093067        4.233512
# 15 to 19         1.855146       1.920361          2.560899        1.604278
# 20 to 24         3.456163       5.196272          5.215490        2.450980
# ...                   ...            ...               ...             ...
# 65 to 69         1.595359       1.267206          0.000000        7.456979
# 70 to 74         2.610587       0.961328          0.833868        6.453155
# 75 to 79         0.749335       1.857112          0.609365        1.625239
# 80 to 84         0.604303       0.284029          0.962155        1.720841
# 85 and up        0.628475       1.594931          3.752405        1.147228
#
# Neighborhood  Jefferson Park Avenue_Fct  Johnson Village_Fct  \
# Age
# 0 to 4                         0.468436             5.317919
# 5 to 9                         0.133839             1.098266
# 10 to 14                       0.401517             5.491329
# 15 to 19                       7.539594             0.867052
# 20 to 24                      34.374303             8.497110
# ...                                 ...                  ...
# 65 to 69                       0.868104             2.813425
# 70 to 74                       0.112013             5.429418
# 75 to 79                       0.140017             3.455084
# 80 to 84                       0.196024             0.789733
# 85 and up                      0.000000             0.000000
#
# Neighborhood  Lewis Mountain_Fct  Locust Grove_Fct  Martha Jefferson_Fct  \
# Age
# 0 to 4                  0.000000          2.555066              7.608696
# 5 to 9                  0.000000          1.233480              3.405797
# 10 to 14                0.000000          2.731278              1.739130
# 15 to 19                9.436275          0.704846              0.000000
# 20 to 24               19.975490          2.863436              3.188406
# ...                          ...               ...                   ...
# 65 to 69               11.040340          2.999063              2.773156
# 70 to 74                0.000000          0.328022              0.000000
# 75 to 79                0.743100          3.561387              1.552967
# 80 to 84                0.424628          1.733833              0.332779
# 85 and up               0.530786          0.749766              0.221852
#
# Neighborhood  North Downtown_Fct  Ridge Street_Fct  Rose Hill_Fct  \
# Age
# 0 to 4                  3.628231          4.597701       0.000000
# 5 to 9                  3.031809          2.813067       0.000000
# 10 to 14                2.087475          1.391410       4.150198
# 15 to 19                1.242545          2.329099       0.592885
# 20 to 24                4.522863          3.024803       6.521739
# ...                          ...               ...            ...
# 65 to 69                2.429150          1.740947       5.797101
# 70 to 74                0.736106          2.715877       5.072464
# 75 to 79                0.699301          0.626741       0.966184
# 80 to 84                0.662495          0.417827       0.724638
# 85 and up               0.220832          0.626741       2.053140
#
# Neighborhood  Starr Hill_Fct  The Meadows_Fct  Venable_Fct  Woolen Mills_Fct  \
# Age
# 0 to 4              0.000000         5.916140     0.689049          3.150407
# 5 to 9              1.456311         1.665709     0.542442          1.016260
# 10 to 14            0.000000         1.665709     0.469139          7.418699
# 15 to 19            0.728155         0.919012     5.145873          0.000000
# 20 to 24            6.674757         2.125215    32.473244          6.707317
# ...                      ...              ...          ...               ...
# 65 to 69            0.913706         1.063830     0.295525         13.909774
# 70 to 74            7.715736         1.823708     0.605122          0.000000
# 75 to 79            0.507614         0.683891     0.154799          2.030075
# 80 to 84            4.974619         0.683891     0.309598          0.000000
# 85 and up           5.482234         4.331307     1.308753          0.751880
#
# Neighborhood  Year
# Age
# 0 to 4        2013
# 5 to 9        2013
# 10 to 14      2013
# 15 to 19      2013
# 20 to 24      2013
# ...            ...
# 65 to 69      2020
# 70 to 74      2020
# 75 to 79      2020
# 80 to 84      2020
# 85 and up     2020
#
# [144 rows x 77 columns]

# %% [markdown]
# dfAgeHood.to_csv('data/ageNeighborhood.csv')

# %% [markdown]
# ### Data retrieval for race and ethnicity:

# %%
censusdata.printtable(censusdata.censustable('acs5', 2019, 'B03002'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B03002_001E  | HISPANIC OR LATINO ORIGIN BY R | !! Estimate Total:                                       | int
# B03002_002E  | HISPANIC OR LATINO ORIGIN BY R | !! !! Estimate Total: Not Hispanic or Latino:            | int
# B03002_003E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: White a | int
# B03002_004E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: Black o | int
# B03002_005E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: America | int
# B03002_006E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: Asian a | int
# B03002_007E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: Native  | int
# B03002_008E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: Some ot | int
# B03002_009E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Not Hispanic or Latino: Two or  | int
# B03002_010E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! !! Estimate Total: Not Hispanic or Latino: Two  | int
# B03002_011E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! !! Estimate Total: Not Hispanic or Latino: Two  | int
# B03002_012E  | HISPANIC OR LATINO ORIGIN BY R | !! !! Estimate Total: Hispanic or Latino:                | int
# B03002_013E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: White alone | int
# B03002_014E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: Black or Af | int
# B03002_015E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: American In | int
# B03002_016E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: Asian alone | int
# B03002_017E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: Native Hawa | int
# B03002_018E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: Some other  | int
# B03002_019E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! Estimate Total: Hispanic or Latino: Two or more | int
# B03002_020E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! !! Estimate Total: Hispanic or Latino: Two or m | int
# B03002_021E  | HISPANIC OR LATINO ORIGIN BY R | !! !! !! !! Estimate Total: Hispanic or Latino: Two or m | int
# -------------------------------------------------------------------------------------------------------------------

# %%
# Function to grab data from Charlottesville City Table B03002
# In: year
# Out: dataframe containing race and ethnicity table for overall city
def get03002DataCity(year):
    # create list of variables to pull
    varList = ['B03002_0{:02d}E'.format(x) for x in [3, 4, 5, 6, 7, 8, 9, 12]]
    # download race data
    df = censusdata.download('acs5', year, 
                             censusdata.censusgeo([('state', '51'), 
                                                   ('county', '540')]),
                             varList)
    df = df.T
    # renaming column and rows
    df = df.rename(columns={df.columns[0]: 'Pop'},
                   index={'B03002_003E': 'White, not Hispanic',
                          'B03002_004E': 'Black, not Hispanic',
                          'B03002_005E': 'American Indian, not Hispanic',
                          'B03002_006E': 'Asian, not Hispanic',
                          'B03002_007E': 'Pacific Islander, not Hispanic',
                          'B03002_008E': 'Some other race, not Hispanic',
                          'B03002_009E': 'Two or more races, not Hispanic',
                          'B03002_012E': 'Hispanic or Latino (may be of any race)'})
    # get total population count
    totalPop = df['Pop'].sum()
    # get pct df from counts
    dfPct = df.apply(lambda x: 100 * x / float(totalPop))
    dfFull = pd.concat([dfPct, df], axis=1, join='inner')
    # add identifier to count variable
    dfFull.columns.values[1] = dfFull.columns.values[1] + 'ct'
    # add year col
    dfFull['Year'] = year

    return dfFull

# %%
def get03002Historical(years, hood = False):
    for year in years:
        if hood:
            if year == years[0]:
                df = get03002DataHood(year)
            else:
                df = pd.concat([df, get03002DataHood(year)])
        else:
            if year == years[0]:
                df = get03002DataCity(year)
            else:
                df = pd.concat([df, get03002DataCity(year)])
    if not hood:
        ag = [f'({df.iloc[i, 1]:,} : {df.iloc[i, 0]:.2f}%)'
              for i in range(df.shape[0])]
        df['ag'] = ag
    df.index.name = 'Race and Ethnicity'
    return df

# %%
dfEthnicity = get03002Historical([year for year in range(2009, 2021)])

# %%
dfEthnicity
# Out:
#                                                Pop  Popct  Year  \
# Race and Ethnicity
# White, not Hispanic                      69.267751  28672  2009
# Black, not Hispanic                      19.885005   8231  2009
# American Indian, not Hispanic             0.074892     31  2009
# Asian, not Hispanic                       4.392047   1818  2009
# Pacific Islander, not Hispanic            0.028990     12  2009
# ...                                            ...    ...   ...
# Asian, not Hispanic                       7.016541   3313  2020
# Pacific Islander, not Hispanic            0.010589      5  2020
# Some other race, not Hispanic             0.332507    157  2020
# Two or more races, not Hispanic           2.770189   1308  2020
# Hispanic or Latino (may be of any race)   5.555203   2623  2020
#
#                                                         ag
# Race and Ethnicity
# White, not Hispanic                      (28,672 : 69.27%)
# Black, not Hispanic                       (8,231 : 19.89%)
# American Indian, not Hispanic                 (31 : 0.07%)
# Asian, not Hispanic                        (1,818 : 4.39%)
# Pacific Islander, not Hispanic                (12 : 0.03%)
# ...                                                    ...
# Asian, not Hispanic                        (3,313 : 7.02%)
# Pacific Islander, not Hispanic                 (5 : 0.01%)
# Some other race, not Hispanic                (157 : 0.33%)
# Two or more races, not Hispanic            (1,308 : 2.77%)
# Hispanic or Latino (may be of any race)    (2,623 : 5.56%)
#
# [96 rows x 4 columns]

# %% [markdown]
# dfEthnicity.to_csv('data/raceEthnicityCity.csv')

# %%
# Function to grab data from Charlottesville City Table B03002
# In: year
# Out: dataframe containing race table for neighborhoods
def get03002DataHood(year):
    # create list of variables to pull
    varList = ['B03002_0{:02d}E'.format(x) for x in [3, 4, 5, 6, 7, 8, 9, 12]]
    # download race data
    df = censusdata.download('acs5', year, 
                             censusdata.censusgeo([('state', '51'), 
                                                   ('county', '540'),
                                                   ('block group', '*')]),
                             varList)
    # add neighborhoods for grouping
    df['Neighborhood'] = ''
    for index, row in df.iterrows():
        if index.geo[2][1][2]:
            # 100 census tract case
            df.loc[index, 'Neighborhood'] = blockNeighborDict[int(index.geo[2][1][2:] + \
                                                                  index.geo[3][1])]
        else:
            # 0xx census tract case
            df.loc[index, 'Neighborhood'] = blockNeighborDict[int(index.geo[2][1][3:] + \
                                                                  index.geo[3][1])]
    # remove nan values and sum neighborhood counts
    df = df.groupby('Neighborhood').sum().astype(int)
    # transpose
    df = df.T
    # renaming column and rows
    df = df.rename(index={'B03002_003E': 'White, not Hispanic',
                          'B03002_004E': 'Black, not Hispanic',
                          'B03002_005E': 'American Indian, not Hispanic',
                          'B03002_006E': 'Asian, not Hispanic',
                          'B03002_007E': 'Pacific Islander, not Hispanic',
                          'B03002_008E': 'Some other race, not Hispanic',
                          'B03002_009E': 'Two or more races, not Hispanic',
                          'B03002_012E': 'Hispanic or Latino (may be of any race)'})
    dfPct = df.apply(lambda x: 100 * x / float(sum(x)))
    dfFull = pd.concat([dfPct, df], axis=1, join='inner')
    dfFull.columns.values[19:] = dfFull.columns.values[19:] + 'ct'
    dfFull['Year'] = year

    return dfFull

# %%
dfRaceEthnicity = get03002Historical([year for year in range(2013, 2021)], True)

# %%
dfRaceEthnicity
# Out:
# Neighborhood                             10th & Page  Barracks / Rugby  \
# Race and Ethnicity
# White, not Hispanic                        19.906868         70.551257
# Black, not Hispanic                        76.600698         13.974855
# American Indian, not Hispanic               0.000000          0.483559
# Asian, not Hispanic                         1.047730          3.916828
# Pacific Islander, not Hispanic              0.000000          0.000000
# ...                                              ...               ...
# Asian, not Hispanic                         9.947984          0.511654
# Pacific Islander, not Hispanic              0.000000          0.000000
# Some other race, not Hispanic               0.000000          0.000000
# Two or more races, not Hispanic             3.706112          1.648664
# Hispanic or Latino (may be of any race)     0.325098          3.638431
#
# Neighborhood                             Barracks Road    Belmont  Fifeville  \
# Race and Ethnicity
# White, not Hispanic                          76.091954  78.653113  33.267439
# Black, not Hispanic                           3.448276  16.365947  51.793279
# American Indian, not Hispanic                 0.000000   0.000000   0.000000
# Asian, not Hispanic                          19.310345   1.880559   6.438859
# Pacific Islander, not Hispanic                0.000000   0.000000   0.706015
# ...                                                ...        ...        ...
# Asian, not Hispanic                          15.483871   1.015228   6.030151
# Pacific Islander, not Hispanic                0.000000   0.000000   0.000000
# Some other race, not Hispanic                 0.000000   0.000000   0.000000
# Two or more races, not Hispanic               2.580645   0.652647   4.041949
# Hispanic or Latino (may be of any race)       2.580645   1.184433   3.736072
#
# Neighborhood                             Fry's Spring  Greenbrier  \
# Race and Ethnicity
# White, not Hispanic                         79.825109   90.730838
# Black, not Hispanic                         11.961274    2.985740
# American Indian, not Hispanic                0.000000    0.000000
# Asian, not Hispanic                          4.434728    0.534759
# Pacific Islander, not Hispanic               0.000000    0.000000
# ...                                               ...         ...
# Asian, not Hispanic                          8.082104    2.007648
# Pacific Islander, not Hispanic               0.000000    0.000000
# Some other race, not Hispanic                0.000000    0.908222
# Two or more races, not Hispanic              4.522130    0.573614
# Hispanic or Latino (may be of any race)      5.420141    1.720841
#
# Neighborhood                             Jefferson Park Avenue  \
# Race and Ethnicity
# White, not Hispanic                                  65.335713
# Black, not Hispanic                                   5.264332
# American Indian, not Hispanic                         1.204551
# Asian, not Hispanic                                  17.443676
# Pacific Islander, not Hispanic                        0.000000
# ...                                                        ...
# Asian, not Hispanic                                  28.087370
# Pacific Islander, not Hispanic                        0.000000
# Some other race, not Hispanic                         0.000000
# Two or more races, not Hispanic                       4.704565
# Hispanic or Latino (may be of any race)               5.488659
#
# Neighborhood                             Johnson Village  Lewis Mountain  \
# Race and Ethnicity
# White, not Hispanic                            54.624277       67.524510
# Black, not Hispanic                            31.445087        3.063725
# American Indian, not Hispanic                   0.000000        0.000000
# Asian, not Hispanic                             9.710983       20.343137
# Pacific Islander, not Hispanic                  0.000000        0.000000
# ...                                                  ...             ...
# Asian, not Hispanic                             3.948667        7.218684
# Pacific Islander, not Hispanic                  0.000000        0.000000
# Some other race, not Hispanic                   0.000000        0.000000
# Two or more races, not Hispanic                 1.233959        3.397028
# Hispanic or Latino (may be of any race)        15.054294        5.201699
#
# Neighborhood                             Locust Grove  Martha Jefferson  \
# Race and Ethnicity
# White, not Hispanic                         85.066079         75.072464
# Black, not Hispanic                          4.273128         12.971014
# American Indian, not Hispanic                0.000000          0.000000
# Asian, not Hispanic                          0.748899          4.565217
# Pacific Islander, not Hispanic               0.000000          0.000000
# ...                                               ...               ...
# Asian, not Hispanic                          5.998126          3.216861
# Pacific Islander, not Hispanic               0.000000          0.277316
# Some other race, not Hispanic                0.000000          0.554631
# Two or more races, not Hispanic              1.546392          0.000000
# Hispanic or Latino (may be of any race)      0.187441          5.047144
#
# Neighborhood                             North Downtown  Ridge Street  \
# Race and Ethnicity
# White, not Hispanic                           87.276342     40.562613
# Black, not Hispanic                            2.783300     47.670901
# American Indian, not Hispanic                  1.242545      0.000000
# Asian, not Hispanic                            0.745527      0.967937
# Pacific Islander, not Hispanic                 0.000000      0.000000
# ...                                                 ...           ...
# Asian, not Hispanic                            1.509017      4.410399
# Pacific Islander, not Hispanic                 0.000000      0.000000
# Some other race, not Hispanic                  0.515274      0.000000
# Two or more races, not Hispanic                3.238866      2.715877
# Hispanic or Latino (may be of any race)        3.312477      8.565460
#
# Neighborhood                             Rose Hill  Starr Hill  The Meadows  \
# Race and Ethnicity
# White, not Hispanic                      52.865613   82.766990    43.653073
# Black, not Hispanic                      41.600791   15.291262    25.674899
# American Indian, not Hispanic             0.000000    0.000000     0.000000
# Asian, not Hispanic                       5.533597    0.000000    15.795520
# Pacific Islander, not Hispanic            0.000000    0.000000     0.000000
# ...                                            ...         ...          ...
# Asian, not Hispanic                       1.207729    1.015228    10.562310
# Pacific Islander, not Hispanic            0.000000    0.000000     0.000000
# Some other race, not Hispanic             0.000000    0.000000     0.000000
# Two or more races, not Hispanic           1.207729    1.522843     2.279635
# Hispanic or Latino (may be of any race)  10.628019    1.725888    14.589666
#
# Neighborhood                               Venable  Woolen Mills  \
# Race and Ethnicity
# White, not Hispanic                      73.215071     76.930894
# Black, not Hispanic                      10.233104     21.036585
# American Indian, not Hispanic             0.205248      0.000000
# Asian, not Hispanic                      10.570298      0.813008
# Pacific Islander, not Hispanic            0.175927      0.000000
# ...                                            ...           ...
# Asian, not Hispanic                       9.344216      0.300752
# Pacific Islander, not Hispanic            0.000000      0.000000
# Some other race, not Hispanic             1.604278      0.000000
# Two or more races, not Hispanic           2.448635     10.601504
# Hispanic or Latino (may be of any race)   6.768928     16.766917
#
# Neighborhood                             10th & Pagect  Barracks / Rugbyct  \
# Race and Ethnicity
# White, not Hispanic                                171                1459
# Black, not Hispanic                                658                 289
# American Indian, not Hispanic                        0                  10
# Asian, not Hispanic                                  9                  81
# Pacific Islander, not Hispanic                       0                   0
# ...                                                ...                 ...
# Asian, not Hispanic                                153                   9
# Pacific Islander, not Hispanic                       0                   0
# Some other race, not Hispanic                        0                   0
# Two or more races, not Hispanic                     57                  29
# Hispanic or Latino (may be of any race)              5                  64
#
# Neighborhood                             Barracks Roadct  Belmontct  \
# Race and Ethnicity
# White, not Hispanic                                  331       3095
# Black, not Hispanic                                   15        644
# American Indian, not Hispanic                          0          0
# Asian, not Hispanic                                   84         74
# Pacific Islander, not Hispanic                         0          0
# ...                                                  ...        ...
# Asian, not Hispanic                                  144         42
# Pacific Islander, not Hispanic                         0          0
# Some other race, not Hispanic                          0          0
# Two or more races, not Hispanic                       24         27
# Hispanic or Latino (may be of any race)               24         49
#
# Neighborhood                             Fifevillect  Fry's Springct  \
# Race and Ethnicity
# White, not Hispanic                             1178            2556
# Black, not Hispanic                             1834             383
# American Indian, not Hispanic                      0               0
# Asian, not Hispanic                              228             142
# Pacific Islander, not Hispanic                    25               0
# ...                                              ...             ...
# Asian, not Hispanic                              276             252
# Pacific Islander, not Hispanic                     0               0
# Some other race, not Hispanic                      0               0
# Two or more races, not Hispanic                  185             141
# Hispanic or Latino (may be of any race)          171             169
#
# Neighborhood                             Greenbrierct  \
# Race and Ethnicity
# White, not Hispanic                              2036
# Black, not Hispanic                                67
# American Indian, not Hispanic                       0
# Asian, not Hispanic                                12
# Pacific Islander, not Hispanic                      0
# ...                                               ...
# Asian, not Hispanic                                42
# Pacific Islander, not Hispanic                      0
# Some other race, not Hispanic                      19
# Two or more races, not Hispanic                    12
# Hispanic or Latino (may be of any race)            36
#
# Neighborhood                             Jefferson Park Avenuect  \
# Race and Ethnicity
# White, not Hispanic                                         2929
# Black, not Hispanic                                          236
# American Indian, not Hispanic                                 54
# Asian, not Hispanic                                          782
# Pacific Islander, not Hispanic                                 0
# ...                                                          ...
# Asian, not Hispanic                                         1003
# Pacific Islander, not Hispanic                                 0
# Some other race, not Hispanic                                  0
# Two or more races, not Hispanic                              168
# Hispanic or Latino (may be of any race)                      196
#
# Neighborhood                             Johnson Villagect  Lewis Mountainct  \
# Race and Ethnicity
# White, not Hispanic                                    945               551
# Black, not Hispanic                                    544                25
# American Indian, not Hispanic                            0                 0
# Asian, not Hispanic                                    168               166
# Pacific Islander, not Hispanic                           0                 0
# ...                                                    ...               ...
# Asian, not Hispanic                                     80                68
# Pacific Islander, not Hispanic                           0                 0
# Some other race, not Hispanic                            0                 0
# Two or more races, not Hispanic                         25                32
# Hispanic or Latino (may be of any race)                305                49
#
# Neighborhood                             Locust Grovect  Martha Jeffersonct  \
# Race and Ethnicity
# White, not Hispanic                                1931                1036
# Black, not Hispanic                                  97                 179
# American Indian, not Hispanic                         0                   0
# Asian, not Hispanic                                  17                  63
# Pacific Islander, not Hispanic                        0                   0
# ...                                                 ...                 ...
# Asian, not Hispanic                                 128                  58
# Pacific Islander, not Hispanic                        0                   5
# Some other race, not Hispanic                         0                  10
# Two or more races, not Hispanic                      33                   0
# Hispanic or Latino (may be of any race)               4                  91
#
# Neighborhood                             North Downtownct  Ridge Streetct  \
# Race and Ethnicity
# White, not Hispanic                                  1756            1341
# Black, not Hispanic                                    56            1576
# American Indian, not Hispanic                          25               0
# Asian, not Hispanic                                    15              32
# Pacific Islander, not Hispanic                          0               0
# ...                                                   ...             ...
# Asian, not Hispanic                                    41             190
# Pacific Islander, not Hispanic                          0               0
# Some other race, not Hispanic                          14               0
# Two or more races, not Hispanic                        88             117
# Hispanic or Latino (may be of any race)                90             369
#
# Neighborhood                             Rose Hillct  Starr Hillct  \
# Race and Ethnicity
# White, not Hispanic                              535           682
# Black, not Hispanic                              421           126
# American Indian, not Hispanic                      0             0
# Asian, not Hispanic                               56             0
# Pacific Islander, not Hispanic                     0             0
# ...                                              ...           ...
# Asian, not Hispanic                               10            10
# Pacific Islander, not Hispanic                     0             0
# Some other race, not Hispanic                      0             0
# Two or more races, not Hispanic                   10            15
# Hispanic or Latino (may be of any race)           88            17
#
# Neighborhood                             The Meadowsct  Venablect  \
# Race and Ethnicity
# White, not Hispanic                                760       4994
# Black, not Hispanic                                447        698
# American Indian, not Hispanic                        0         14
# Asian, not Hispanic                                275        721
# Pacific Islander, not Hispanic                       0         12
# ...                                                ...        ...
# Asian, not Hispanic                                139        664
# Pacific Islander, not Hispanic                       0          0
# Some other race, not Hispanic                        0        114
# Two or more races, not Hispanic                     30        174
# Hispanic or Latino (may be of any race)            192        481
#
# Neighborhood                             Woolen Millsct  Year
# Race and Ethnicity
# White, not Hispanic                                 757  2013
# Black, not Hispanic                                 207  2013
# American Indian, not Hispanic                         0  2013
# Asian, not Hispanic                                   8  2013
# Pacific Islander, not Hispanic                        0  2013
# ...                                                 ...   ...
# Asian, not Hispanic                                   4  2020
# Pacific Islander, not Hispanic                        0  2020
# Some other race, not Hispanic                         0  2020
# Two or more races, not Hispanic                     141  2020
# Hispanic or Latino (may be of any race)             223  2020
#
# [64 rows x 39 columns]

# %% [markdown]
# dfRaceEthnicity.to_csv('data/raceEthnicityNeighborhood.csv')

# %% [markdown]
# ### Data retrieval for income:

# %%
censusdata.printtable(censusdata.censustable('acs5', 2019, 'B19001'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B19001_001E  | HOUSEHOLD INCOME IN THE PAST 1 | !! Estimate Total:                                       | int
# B19001_002E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: Less than $10,000                  | int
# B19001_003E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $10,000 to $14,999                 | int
# B19001_004E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $15,000 to $19,999                 | int
# B19001_005E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $20,000 to $24,999                 | int
# B19001_006E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $25,000 to $29,999                 | int
# B19001_007E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $30,000 to $34,999                 | int
# B19001_008E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $35,000 to $39,999                 | int
# B19001_009E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $40,000 to $44,999                 | int
# B19001_010E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $45,000 to $49,999                 | int
# B19001_011E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $50,000 to $59,999                 | int
# B19001_012E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $60,000 to $74,999                 | int
# B19001_013E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $75,000 to $99,999                 | int
# B19001_014E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $100,000 to $124,999               | int
# B19001_015E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $125,000 to $149,999               | int
# B19001_016E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $150,000 to $199,999               | int
# B19001_017E  | HOUSEHOLD INCOME IN THE PAST 1 | !! !! Estimate Total: $200,000 or more                   | int
# -------------------------------------------------------------------------------------------------------------------

# %%
# Function to grab data from Charlottesville City Table B19001
# In: year
# Out: dataframe containing income table for overall city
def get19001DataCity(year):
    # create list of variables to pull
    varList = ['B19001_0{:02d}E'.format(x) for x in range(2, 18)]
    # download income data
    df = censusdata.download('acs5', year, 
                             censusdata.censusgeo([('state', '51'), 
                                                   ('county', '540')]),
                             varList)
    df = df.T
    # renaming column and rows
    df = df.rename(columns={df.columns[0]: 'Income'},
                   index={'B19001_002E': 'Less than $10,000',
                          'B19001_003E': '$10,000 to 14,999',
                          'B19001_004E': '$15,000 to 19,999',
                          'B19001_005E': '$20,000 to 24,999',
                          'B19001_006E': '$25,000 to 29,999',
                          'B19001_007E': '$30,000 to 34,999',
                          'B19001_008E': '$35,000 to 39,999', 
                          'B19001_009E': '$40,000 to 44,999', 
                          'B19001_010E': '$45,000 to 49,999', 
                          'B19001_011E': '$50,000 to 59,999', 
                          'B19001_012E': '$60,000 to 74,999', 
                          'B19001_013E': '$75,000 to 99,999', 
                          'B19001_014E': '$100,000 to 124,999', 
                          'B19001_015E': '$125,000 to 149,999', 
                          'B19001_016E': '$150,000 to 199,999', 
                          'B19001_017E': '$200,000 or more'})
    # get total population count
    totalPop = df['Income'].sum()
    # get pct df from counts
    dfPct = df.apply(lambda x: 100 * x / float(totalPop))
    dfFull = pd.concat([dfPct, df], axis=1, join='inner')
    dfFull.columns.values[1] = dfFull.columns.values[1] + 'ct'
    dfFull['Year'] = year

    return dfFull

# %%
def get19001Historical(years, hood = False):
    for year in years:
        if hood:
            if year == years[0]:
                df = get19001DataHood(year)
            else:
                df = pd.concat([df, get19001DataHood(year)])
        else:
            if year == years[0]:
                df = get19001DataCity(year)
            else:
                df = pd.concat([df, get19001DataCity(year)])
    if not hood:
        ag = [f'({df.iloc[i, 1]:,} : {df.iloc[i, 0]:.2f}%)'
              for i in range(df.shape[0])]
        df['ag'] = ag
    df.index.name = 'Bracket'
    return df

# %%
dfIncome = get19001Historical([year for year in range(2009, 2021)])

# %%
dfIncome
# Out:
#                         Income  Incomect  Year                ag
# Bracket
# Less than $10,000    15.618947      2661  2009  (2,661 : 15.62%)
# $10,000 to 14,999     6.145448      1047  2009   (1,047 : 6.15%)
# $15,000 to 19,999     6.239361      1063  2009   (1,063 : 6.24%)
# $20,000 to 24,999     9.091976      1549  2009   (1,549 : 9.09%)
# $25,000 to 29,999     4.736749       807  2009     (807 : 4.74%)
# ...                        ...       ...   ...               ...
# $75,000 to 99,999    12.267460      2308  2020  (2,308 : 12.27%)
# $100,000 to 124,999   8.408632      1582  2020   (1,582 : 8.41%)
# $125,000 to 149,999   5.798873      1091  2020   (1,091 : 5.80%)
# $150,000 to 199,999   7.494419      1410  2020   (1,410 : 7.49%)
# $200,000 or more      8.961412      1686  2020   (1,686 : 8.96%)
#
# [192 rows x 4 columns]

# %% [markdown]
# dfIncome.to_csv('data/incomeCity.csv')

# %%
# Function to grab data from Charlottesville City Table B19001
# In: year
# Out: dataframe containing income table for neighborhoods
def get19001DataHood(year):
    # create list of variables to pull
    varList = ['B19001_0{:02d}E'.format(x) for x in range(2, 18)]
    # download income data
    df = censusdata.download('acs5', year, 
                             censusdata.censusgeo([('state', '51'), 
                                                   ('county', '540'),
                                                   ('block group', '*')]),
                             varList)
    # add neighborhoods for grouping
    df['Neighborhood'] = ''
    for index, row in df.iterrows():
        if index.geo[2][1][2]:
            # 100 census tract case
            df.loc[index, 'Neighborhood'] = blockNeighborDict[int(index.geo[2][1][2:] + \
                                                                  index.geo[3][1])]
        else:
            # 0xx census tract case
            df.loc[index, 'Neighborhood'] = blockNeighborDict[int(index.geo[2][1][3:] + \
                                                                  index.geo[3][1])]
    # remove nan values and sum neighborhood counts
    df = df.groupby('Neighborhood').sum().astype(int)
    # transpose
    df = df.T
    # renaming column and rows
    df = df.rename(index={'B19001_002E': 'Less than $10,000',
                          'B19001_003E': '$10,000 to 14,999',
                          'B19001_004E': '$15,000 to 19,999',
                          'B19001_005E': '$20,000 to 24,999',
                          'B19001_006E': '$25,000 to 29,999',
                          'B19001_007E': '$30,000 to 34,999',
                          'B19001_008E': '$35,000 to 39,999', 
                          'B19001_009E': '$40,000 to 44,999', 
                          'B19001_010E': '$45,000 to 49,999', 
                          'B19001_011E': '$50,000 to 59,999', 
                          'B19001_012E': '$60,000 to 74,999', 
                          'B19001_013E': '$75,000 to 99,999', 
                          'B19001_014E': '$100,000 to 124,999', 
                          'B19001_015E': '$125,000 to 149,999', 
                          'B19001_016E': '$150,000 to 199,999', 
                          'B19001_017E': '$200,000 or more'})
    dfPct = df.apply(lambda x: 100 * x / float(sum(x)))
    dfFull = pd.concat([dfPct, df], axis=1, join='inner')
    dfFull.columns.values[19:] = dfFull.columns.values[19:] + 'ct'
    dfFull['Year'] = year

    return dfFull

# %%
dfIncomeHist = get19001Historical([year for year in range(2013, 2021)], True)

# %%
dfIncomeHist
# Out:
# Neighborhood         10th & Page  Barracks / Rugby  Barracks Road    Belmont  \
# Bracket
# Less than $10,000      21.460177          9.081633      19.200000  11.011591
# $10,000 to 14,999       8.407080          2.857143       8.800000   7.218124
# $15,000 to 19,999      11.504425          0.000000      24.800000   6.375132
# $20,000 to 24,999      18.362832          2.244898       6.400000  11.116965
# $25,000 to 29,999       7.964602          3.163265       5.600000   4.004215
# ...                          ...               ...            ...        ...
# $75,000 to 99,999      19.026549         15.107914       9.352518  11.231203
# $100,000 to 124,999     2.654867          4.460432       6.954436  11.372180
# $125,000 to 149,999     9.070796          6.187050       2.637890   3.054511
# $150,000 to 199,999     6.637168         26.618705       0.000000   4.934211
# $200,000 or more        0.000000         14.964029       0.000000   6.672932
#
# Neighborhood         Fifeville  Fry's Spring  Greenbrier  \
# Bracket
# Less than $10,000    11.988514      7.676903    0.000000
# $10,000 to 14,999     5.096913      5.740988    0.765864
# $15,000 to 19,999     4.737976      0.000000    2.844639
# $20,000 to 24,999     6.748026      4.205607    1.312910
# $25,000 to 29,999     8.470926      7.610147    2.078775
# ...                        ...           ...         ...
# $75,000 to 99,999    12.244898     14.538153    8.997722
# $100,000 to 124,999   8.643457     11.646586   25.284738
# $125,000 to 149,999   5.042017     12.128514    5.239180
# $150,000 to 199,999   4.741897      8.755020    8.086560
# $200,000 or more      0.660264     10.843373   19.817768
#
# Neighborhood         Jefferson Park Avenue  Johnson Village  Lewis Mountain  \
# Bracket
# Less than $10,000                34.869326         7.226891       29.914530
# $10,000 to 14,999                 3.782669         0.000000        3.418803
# $15,000 to 19,999                 5.914718         2.521008        0.000000
# $20,000 to 24,999                 3.026135         6.050420        2.136752
# $25,000 to 29,999                10.041265         0.000000        0.000000
# ...                                    ...              ...             ...
# $75,000 to 99,999                 7.450980         7.994924        6.349206
# $100,000 to 124,999               1.411765         6.218274        7.936508
# $125,000 to 149,999               3.058824        12.309645        6.349206
# $150,000 to 199,999               0.313725         6.979695       21.428571
# $200,000 or more                  3.294118        26.395939       36.507937
#
# Neighborhood         Locust Grove  Martha Jefferson  North Downtown  \
# Bracket
# Less than $10,000        2.436647          4.360465        0.597015
# $10,000 to 14,999        2.046784         13.808140        2.786070
# $15,000 to 19,999        4.483431          2.034884        3.681592
# $20,000 to 24,999        1.949318          2.616279        7.562189
# $25,000 to 29,999        6.432749          3.779070        5.870647
# ...                           ...               ...             ...
# $75,000 to 99,999       15.610860         18.154762       20.872274
# $100,000 to 124,999      9.615385          4.563492        7.943925
# $125,000 to 149,999      7.692308          4.861111        7.943925
# $150,000 to 199,999      8.936652          7.936508       13.395639
# $200,000 or more        13.009050          6.349206       11.137072
#
# Neighborhood         Ridge Street  Rose Hill  Starr Hill  The Meadows  \
# Bracket
# Less than $10,000       22.996255  21.529745    9.302326    32.220367
# $10,000 to 14,999        2.846442   2.549575    6.440072     3.505843
# $15,000 to 19,999        7.565543   5.099150    4.114490     9.015025
# $20,000 to 24,999        1.573034  15.580737    7.155635     5.843072
# $25,000 to 29,999        6.516854   0.000000    6.082290     8.347245
# ...                           ...        ...         ...          ...
# $75,000 to 99,999       10.740993   4.395604   12.166172     7.504363
# $100,000 to 124,999      6.866077   2.197802   21.810089    15.706806
# $125,000 to 149,999      5.846363   0.000000    3.709199     8.726003
# $150,000 to 199,999      7.817811   8.241758    8.456973     1.745201
# $200,000 or more        14.140041   0.000000   10.979228     0.000000
#
# Neighborhood           Venable  Woolen Mills  10th & Pagect  \
# Bracket
# Less than $10,000    40.626632     12.142857             97
# $10,000 to 14,999     3.812010      0.000000             38
# $15,000 to 19,999     8.093995      5.714286             52
# $20,000 to 24,999     3.603133      1.428571             83
# $25,000 to 29,999     1.096606      1.904762             36
# ...                        ...           ...            ...
# $75,000 to 99,999     5.645534     31.886477             86
# $100,000 to 124,999   2.313744      6.844741             12
# $125,000 to 149,999   3.100416      8.514190             41
# $150,000 to 199,999   7.913003      0.667780             30
# $200,000 or more      7.311430      2.671119              0
#
# Neighborhood         Barracks / Rugbyct  Barracks Roadct  Belmontct  \
# Bracket
# Less than $10,000                    89               24        209
# $10,000 to 14,999                    28               11        137
# $15,000 to 19,999                     0               31        121
# $20,000 to 24,999                    22                8        211
# $25,000 to 29,999                    31                7         76
# ...                                 ...              ...        ...
# $75,000 to 99,999                   105               39        239
# $100,000 to 124,999                  31               29        242
# $125,000 to 149,999                  43               11         65
# $150,000 to 199,999                 185                0        105
# $200,000 or more                    104                0        142
#
# Neighborhood         Fifevillect  Fry's Springct  Greenbrierct  \
# Bracket
# Less than $10,000            167             115             0
# $10,000 to 14,999             71              86             7
# $15,000 to 19,999             66               0            26
# $20,000 to 24,999             94              63            12
# $25,000 to 29,999            118             114            19
# ...                          ...             ...           ...
# $75,000 to 99,999            204             181            79
# $100,000 to 124,999          144             145           222
# $125,000 to 149,999           84             151            46
# $150,000 to 199,999           79             109            71
# $200,000 or more              11             135           174
#
# Neighborhood         Jefferson Park Avenuect  Johnson Villagect  \
# Bracket
# Less than $10,000                        507                 43
# $10,000 to 14,999                         55                  0
# $15,000 to 19,999                         86                 15
# $20,000 to 24,999                         44                 36
# $25,000 to 29,999                        146                  0
# ...                                      ...                ...
# $75,000 to 99,999                         95                 63
# $100,000 to 124,999                       18                 49
# $125,000 to 149,999                       39                 97
# $150,000 to 199,999                        4                 55
# $200,000 or more                          42                208
#
# Neighborhood         Lewis Mountainct  Locust Grovect  Martha Jeffersonct  \
# Bracket
# Less than $10,000                  70              25                  30
# $10,000 to 14,999                   8              21                  95
# $15,000 to 19,999                   0              46                  14
# $20,000 to 24,999                   5              20                  18
# $25,000 to 29,999                   0              66                  26
# ...                               ...             ...                 ...
# $75,000 to 99,999                  16             138                 183
# $100,000 to 124,999                20              85                  46
# $125,000 to 149,999                16              68                  49
# $150,000 to 199,999                54              79                  80
# $200,000 or more                   92             115                  64
#
# Neighborhood         North Downtownct  Ridge Streetct  Rose Hillct  \
# Bracket
# Less than $10,000                   6             307           76
# $10,000 to 14,999                  28              38            9
# $15,000 to 19,999                  37             101           18
# $20,000 to 24,999                  76              21           55
# $25,000 to 29,999                  59              87            0
# ...                               ...             ...          ...
# $75,000 to 99,999                 268             158           16
# $100,000 to 124,999               102             101            8
# $125,000 to 149,999               102              86            0
# $150,000 to 199,999               172             115           30
# $200,000 or more                  143             208            0
#
# Neighborhood         Starr Hillct  The Meadowsct  Venablect  Woolen Millsct  \
# Bracket
# Less than $10,000              52            193        778              51
# $10,000 to 14,999              36             21         73               0
# $15,000 to 19,999              23             54        155              24
# $20,000 to 24,999              40             35         69               6
# $25,000 to 29,999              34             50         21               8
# ...                           ...            ...        ...             ...
# $75,000 to 99,999              82             43        122             191
# $100,000 to 124,999           147             90         50              41
# $125,000 to 149,999            25             50         67              51
# $150,000 to 199,999            57             10        171               4
# $200,000 or more               74              0        158              16
#
# Neighborhood         Year
# Bracket
# Less than $10,000    2013
# $10,000 to 14,999    2013
# $15,000 to 19,999    2013
# $20,000 to 24,999    2013
# $25,000 to 29,999    2013
# ...                   ...
# $75,000 to 99,999    2020
# $100,000 to 124,999  2020
# $125,000 to 149,999  2020
# $150,000 to 199,999  2020
# $200,000 or more     2020
#
# [128 rows x 39 columns]

# %% [markdown]
# dfIncomeHist.to_csv('data/incomeNeighborhood.csv')
